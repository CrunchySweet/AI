# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://collegescorecard.ed.gov/search/?state=CO&cip4=1107&page=0&sort=threshold_earnings:desc"
response =requests.get(url)
html_con = response.text
soup = BeautifulSoup(html_con, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html data-html-server-rendered="true" data-vue-tag="%7B%22lang%22:%7B%22ssr%22:%22en%22%7D%7D" lang="en">
# <head>
# ...
